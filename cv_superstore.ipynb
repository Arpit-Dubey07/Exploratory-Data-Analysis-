# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\91771\\OneDrive\\Desktop\\datasets\\project\\Sample - Superstore.csv",encoding='latin-1')

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 2       3  CA-2016-138688  06-12-2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10-11-2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10-11-2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# ### We have dataset which contains some information of a super store, the details of the columns are as follow
#
# 1. **Row ID**: Unique identifier for each row in the dataset.
# 2. **Order ID**: Unique identifier for each order.
# 3. **Order Date**: Date when the order was placed.
# 4. **Ship Date**: Date when the order was shipped.
# 5. **Ship Mode**: Shipping mode used for the order (e.g., standard, express).
# 6. **Customer ID**: Unique identifier for each customer.
# 7. **Customer Name**: Name of the customer.
# 8. **Segment**: Segment to which the customer belongs (e.g., consumer, corporate).
# 9. **Country**: Country where the order was placed.
# 10. **City**: City where the order was placed.
# 11. **State**: State where the order was placed.
# 12. **Postal Code**: Postal code of the location where the order was placed.
# 13. **Region**: Region where the order was placed.
# 14. **Product ID**: Unique identifier for each product.
# 15. **Category**: Category to which the product belongs (e.g., office supplies, technology).
# 16. **Sub-Category**: Sub-category to which the product belongs (e.g., paper, phones).
# 17. **Product Name**: Name of the product.
# 18. **Sales**: Total sales amount for the order.
# 19. **Quantity**: Quantity of the product ordered.
# 20. **Discount**: Discount applied to the order.
# 21. **Profit**: Profit generated from the order.

# %%
#1. **Total Sales Amount**:
#    - What is the total sales amount in the dataset?
df["Sales"].sum()
# Out:
# 2297200.8603000003

# %%
# 2. **Sales Variation Over Time**:
#    - How do sales vary over time? Can you identify any seasonal trends or patterns in sales?
temp=df.groupby("Category")["Sales"].sum().sort_values(ascending=False).reset_index()

# Category	Sales
# 0	Technology	836154.0330
# 1	Furniture	741999.7953
# 2	Office Supplies	719047.0320

# %%
plt.pie(temp['Sales'],labels=temp["Category"],autopct='%0.1f%%')
plt.show()

# %% [markdown]
# better use bar graph for better visuals

# %% [markdown]
# # obeservation from above pie chart
# - almost all category contributes same but techonology is slightly higher this is may be because there huge demand of technology in almost all field .
# - furniture and office supplies contribute same this may be because each office try to good infrastruture hence there is equal sales of furniture

# %%
temp=df.groupby('Sub-Category')["Sales"].sum().reset_index()
# 	Sub-Category	Sales
# 0	Phones	330007.0540
# 1	Chairs	328449.1030
# 2	Storage	223843.6080
# 3	Tables	206965.5320
# 4	Binders	203412.7330
# 5	Machines	189238.6310
# 6	Accessories	167380.3180
# 7	Copiers	149528.0300
# 8	Bookcases	114879.9963
# 9	Appliances	107532.1610
# 10	Furnishings	91705.1640
# 11	Paper	78479.2060
# 12	Supplies	46673.5380
# 13	Art	27118.7920
# 14	Envelopes	16476.4020
# 15	Labels	12486.3120
# 16	Fasteners	3024.2800

# %%
plt.barh(temp["Sub-Category"],temp["Sales"])
# Out:
# <BarContainer object of 17 artists>

# %% [markdown]
# ## observation from above bar graph
# - we can see that phone and chairs contribute max and fasteners are least it may be because there is high competiotion for fasterners as compare to the chaires or else may be if wfh increased then also there
# is high demand of chairs and phones for office related works and it is not the case for fasterners.

# %%
df["Order Date"]=df["Order Date"].str.replace("-","/")

# %%
df["year"]=df['Order Date'].str.split("/").str[2]

# %%
df["months"]=df['Order Date'].str.split("/").str[0]
df["months"]=df["months"].astype(np.int32)

# %%
temp=df.groupby(["year"])["Sales"].sum().sort_values(ascending=False).reset_index()

# year	Sales
# 0	2017	733215.2552
# 1	2016	609205.5980
# 2	2014	484247.4981
# 3	2015	470532.5090

# %%
plt.pie(temp['Sales'],labels=temp["year"],autopct='%0.1f%%')
plt.title("Sales per year")
plt.show()

# %% [markdown]
# ## observation from above graph
# - clearly there is very much boom in sales in 2017 as compare to all other previous year it shows company doing well in 2017.

# %%
pivot_2017=df[df["year"]=='2017'].groupby("months")["Sales"].sum().sort_index()
pivot_2016=df[df["year"]=='2016'].groupby("months")["Sales"].sum().sort_index()
pivot_2015=df[df["year"]=='2015'].groupby("months")["Sales"].sum().sort_index()
pivot_2014=df[df["year"]=='2014'].groupby("months")["Sales"].sum().sort_index()
pivot_year=pd.concat([pivot_2014,pivot_2015,pivot_2016,pivot_2017],axis=1)
pivot_year.columns=["2014","2015","2016","2017"]
pivot_year.reset_index()
# Out:
#     months        2014        2015        2016         2017
# 0        1  14236.8950  18174.0756  18542.4910   43971.3740
# 1        2   4519.8920  11951.4110  22978.8150   20301.1334
# 2        3  55691.0090  38726.2520  51715.8750   58872.3528
# 3        4  28295.3450  34195.2085  38750.0390   36521.5361
# 4        5  23648.2870  30131.6865  56987.7280   44261.1102
# 5        6  34595.1276  24797.2920  40344.5340   52981.7257
# 6        7  33946.3930  28765.3250  39261.9630   45264.4160
# 7        8  27909.4685  36898.3322  31115.3743   63120.8880
# 8        9  81777.3508  64595.9180  73410.0249   87866.6520
# 9       10  31453.3930  31404.9235  59687.7450   77776.9232
# 10      11  78628.7167  75972.5635  79411.9658  118447.8250
# 11      12  69545.6205  74919.5212  96999.0430   83829.3188

# %%
sns.heatmap(pivot_year,annot=True,cmap='coolwarm')
plt.title("year wise and month wise overall sales")
# Out:
# Text(0.5, 1.0, 'year wise and month wise overall sales')

# %% [markdown]
# ## observation from above heatmap
# - overall sales is usually increasing in the month of march may be because of quarter end of year or for promotional periods
# - sales is usually high in month of sepetember,october,november,december this may be because of holiday season and festivals.

# %%
pivot_2017=df[df["year"]=='2017'].groupby("months")['Sub-Category'].agg(lambda x: x.mode()[0]).sort_index()
pivot_2016=df[df["year"]=='2016'].groupby("months")['Sub-Category'].agg(lambda x: x.mode()[0]).sort_index()
pivot_2015=df[df["year"]=='2015'].groupby("months")['Sub-Category'].agg(lambda x: x.mode()[0]).sort_index()
pivot_2014=df[df["year"]=='2014'].groupby("months")['Sub-Category'].agg(lambda x: x.mode()[0]).sort_index()
pivot_year_catgr=pd.concat([pivot_2014,pivot_2015,pivot_2016,pivot_2017],axis=1)
pivot_year_catgr.columns=["2014","2015","2016","2017"]
pivot_year_catgr.reset_index()
# Out:
#     months         2014     2015         2016     2017
# 0        1      Binders    Paper      Binders  Binders
# 1        2      Binders  Binders  Furnishings    Paper
# 2        3        Paper    Paper      Binders  Binders
# 3        4      Binders  Binders      Binders  Binders
# 4        5      Binders    Paper        Paper  Binders
# 5        6      Binders  Binders        Paper    Paper
# 6        7      Binders  Binders      Binders  Binders
# 7        8        Paper  Binders      Binders  Binders
# 8        9        Paper  Binders      Binders    Paper
# 9       10      Binders  Binders      Binders    Paper
# 10      11        Paper  Binders      Binders  Binders
# 11      12  Furnishings    Paper      Binders  Binders

# %% [markdown]
# # observation
# - we can see that moslty every year and months people normally buys binders and papers for most of the time it shows the it is major factor for overall growth of the company.

# %%
df["sales amount per unit"]=df["Sales"]/df["Quantity"]

# %%
df["sales amount per unit"].mean()
# Out:
# 60.91956905143086

# %% [markdown]
# ## average sales amount is 60.91956

# %%
# <!-- 1. **Commonly Used Shipping Modes**:
#    - What are the most common shipping modes used? -->
temp=df['Ship Mode'].value_counts().reset_index()

# Ship Mode	count
# 0	Standard Class	5968
# 1	Second Class	1945
# 2	First Class	1538
# 3	Same Day	543

# %%
plt.pie(temp['count'],labels=temp["Ship Mode"],autopct='%0.1f%%')
plt.show()

# %% [markdown]
# ## observation
# - mostly shiping mode is standard class and least in same day mode this shows that mostly customer never buys product in hurry they usually order 3-4 days before.

# %%
df["Order Date"]=pd.to_datetime(df["Order Date"])

# %%
df["Ship Date"]=df["Ship Date"].str.replace("-","/")

# %%
df["Ship Date"]=pd.to_datetime(df["Ship Date"])

# %%
df["delivery time"]=df["Ship Date"]-df["Order Date"]

# %%
df["delivery time"].sort_values()
# Out:
# 2113   0 days
# 6191   0 days
# 2865   0 days
# 2864   0 days
# 5073   0 days
#         ...
# 3419   7 days
# 1059   7 days
# 9515   7 days
# 5291   7 days
# 7123   7 days
# Name: delivery time, Length: 9994, dtype: timedelta64[ns]

# %%
df.groupby("Ship Mode")["delivery time"].describe()
# Out:
#                count                       mean                        std  \
# Ship Mode
# First Class     1538  2 days 04:23:05.695708712  0 days 18:33:52.921370074
# Same Day         543  0 days 01:03:38.784530386  0 days 04:56:14.749306559
# Second Class    1945  3 days 05:42:47.197943444  1 days 04:31:04.369531051
# Standard Class  5968  5 days 00:09:24.611260053  1 days 00:15:34.279952478
#
#                             min              25%              50%  \
# Ship Mode
# First Class     1 days 00:00:00  2 days 00:00:00  2 days 00:00:00
# Same Day        0 days 00:00:00  0 days 00:00:00  0 days 00:00:00
# Second Class    1 days 00:00:00  2 days 00:00:00  3 days 00:00:00
# Standard Class  3 days 00:00:00  4 days 00:00:00  5 days 00:00:00
#
#                             75%              max
# Ship Mode
# First Class     3 days 00:00:00  4 days 00:00:00
# Same Day        0 days 00:00:00  1 days 00:00:00
# Second Class    4 days 00:00:00  5 days 00:00:00
# ...

# %% [markdown]
# # observation
# - people mostly order product  from standard class.
# - average time for standard class is 5 days this shows that people usually palced the order atleast 5 days ago .
# - for standard class min time is 3 days and max is 7 days then also people opting this mode as compare to other mode means customer are ok even if product shiped late.

# %%
# 1. **Top Customers by Total Sales**:
#    - Who are the top customers in terms of total sales?
df.groupby(["Customer Name"])["Sales"].sum().sort_values(ascending=False).head(10).reset_index()
# Out:
#         Customer Name      Sales
# 0         Sean Miller  25043.050
# 1        Tamara Chand  19052.218
# 2        Raymond Buch  15117.339
# 3        Tom Ashbrook  14595.620
# 4       Adrian Barton  14473.571
# 5        Ken Lonsdale  14175.229
# 6        Sanjit Chand  14142.334
# 7        Hunter Lopez  12873.298
# 8        Sanjit Engle  12209.438
# 9  Christopher Conant  12129.072

# %%
# 2. **Distribution of Customers Across Segments**:
#    - What is the distribution of customers across different segments?
df.groupby(['Segment','Customer Name'])["Sales"].sum().nlargest(10).reset_index()
# Out:
#        Segment       Customer Name      Sales
# 0  Home Office         Sean Miller  25043.050
# 1    Corporate        Tamara Chand  19052.218
# 2     Consumer        Raymond Buch  15117.339
# 3  Home Office        Tom Ashbrook  14595.620
# 4     Consumer       Adrian Barton  14473.571
# 5     Consumer        Ken Lonsdale  14175.229
# 6     Consumer        Sanjit Chand  14142.334
# 7     Consumer        Hunter Lopez  12873.298
# 8     Consumer        Sanjit Engle  12209.438
# 9     Consumer  Christopher Conant  12129.072

# %% [markdown]
# # graphing and need more observation

# %% [markdown]
# # question 3 solved

# %%
# 1. **Countries Contributing Most to Sales**:
#    - Which countries contribute the most to sales?
# invalid for this data set

# %%
# 2. **Regional Differences in Sales Performance**:
#    - Are there any regional differences in sales performance?
temp=df.groupby('Region')["Sales"].sum().reset_index()

# Region	Sales
# 0	Central	501239.8908
# 1	East	678781.2400
# 2	South	391721.9050
# 3	West	725457.8245

# %%
plt.pie(temp['Sales'],labels=temp["Region"],autopct='%0.1f%%')
plt.show()

# %%
# 3. **Sales Patterns Based on Cities or States**:
#    - Can you identify any patterns in sales based on cities or states?
df.groupby('State')["Sales"].sum().sort_values(ascending=False).reset_index()
# Out:
#                    State        Sales
# 0             California  457687.6315
# 1               New York  310876.2710
# 2                  Texas  170188.0458
# 3             Washington  138641.2700
# 4           Pennsylvania  116511.9140
# 5                Florida   89473.7080
# 6               Illinois   80166.1010
# 7                   Ohio   78258.1360
# 8               Michigan   76269.6140
# 9               Virginia   70636.7200
# 10        North Carolina   55603.1640
# 11               Indiana   53555.3600
# 12               Georgia   49095.8400
# 13              Kentucky   36591.7500
# 14            New Jersey   35764.3120
# 15               Arizona   35282.0010
# 16             Wisconsin   32114.6100
# 17              Colorado   32108.1180
# 18             Tennessee   30661.8730
# 19             Minnesota   29863.1500
# 20         Massachusetts   28634.4340
# 21              Delaware   27451.0690
# 22              Maryland   23705.5230
# 23          Rhode Island   22627.9560
# ...

# %% [markdown]
# # observation
# - From above table we can see that California, New York, Texas are the top states where sales is max!

# %%
df.groupby('Product Name')['Profit'].sum().sort_values(ascending=False).head(10).reset_index()
# Out:
#                                         Product Name      Profit
# 0              Canon imageCLASS 2200 Advanced Copier  25199.9280
# 1  Fellowes PB500 Electric Punch Plastic Comb Bin...   7753.0390
# 2               Hewlett Packard LaserJet 3310 Copier   6983.8836
# 3                 Canon PC1060 Personal Laser Copier   4570.9347
# 4  HP Designjet T520 Inkjet Large Format Printer ...   4094.9766
# 5                  Ativa V4110MDD Micro-Cut Shredder   3772.9461
# 6   3D Systems Cube Printer, 2nd Generation, Magenta   3717.9714
# 7  Plantronics Savi W720 Multi-Device Wireless He...   3696.2820
# 8               Ibico EPK-21 Electric Binding System   3345.2823
# 9                  Zebra ZM400 Thermal Label Printer   3343.5360

# %%
temp=df[['Quantity','sales amount per unit','Discount','Sales']].corr().reset_index()

#     index	Quantity	sales amount per unit	Discount	Sales
# 0	Quantity	1.000000	-0.003148	0.008623	0.200795
# 1	sales amount per unit	-0.003148	1.000000	-0.032803	0.889376
# 2	Discount	0.008623	-0.032803	1.000000	-0.028190
# 3	Sales	0.200795	0.889376	-0.028190	1.000000

# %%
i=1
j=1
for i in range(len(temp)):
    for j in range(1,i):
        if (temp.iloc[i, j] > 0):
            print(" "+temp.columns[i]+","+ temp.columns[j]+f" and correlation is {temp.iloc[i,j]}")
# Out:
#  sales amount per unit,Quantity and correlation is 0.008622970271156362
#  Discount,Quantity and correlation is 0.20079477137389737
#  Discount,sales amount per unit and correlation is 0.8893759811482347

# %%
sns.relplot(data=df,x=df["Quantity"],y=df["sales amount per unit"],kind="scatter",row=1,col=1)
sns.relplot(data=df,x=df["Discount"],y=df["Quantity"],kind="scatter",row=1,col=2)

# %%
# 1. **Overall Profit Margin**:
#    - What is the overall profit margin for the dataset?
df["Profit"].sum()
# Out:
# 286397.0217

# %%
# 2. **Trends or Patterns in Profit Over Time**:
#    - Are there any trends or patterns in profit over time?
pivot_2017=df[df["year"]=='2017'].groupby("months")["Profit"].sum().sort_index()
pivot_2016=df[df["year"]=='2016'].groupby("months")["Profit"].sum().sort_index()
pivot_2015=df[df["year"]=='2015'].groupby("months")["Profit"].sum().sort_index()
pivot_2014=df[df["year"]=='2014'].groupby("months")["Profit"].sum().sort_index()
pivot_year_profit=pd.concat([pivot_2014,pivot_2015,pivot_2016,pivot_2017],axis=1)
pivot_year_profit.columns=["2014's profit","2015's profit","2016's profit","2017's profit"]
pivot_year_profit.reset_index()
# Out:
#     months  2014's profit  2015's profit  2016's profit  2017's profit
# 0        1      2450.1907     -3281.0070      2824.8233      7140.4391
# 1        2       862.3084      2813.8508      5004.5795      1613.8720
# 2        3       498.7299      9732.0978      3611.9680     14751.8915
# 3        4      3488.8352      4187.4962      2977.8149       933.2900
# 4        5      2738.7096      4667.8690      8662.1464      6342.5828
# 5        6      4976.5244      3335.5572      4750.3781      8223.3357
# 6        7      -841.4826      3288.6483      4432.8779      6952.6212
# 7        8      5318.1050      5355.8084      2062.0693      9040.9557
# 8        9      8328.0994      8209.1627      9328.6576     10991.5556
# 9       10      3448.2573      2817.3660     16243.1425      9275.2755
# 10      11      9292.1269     12474.7884      4011.4075      9690.1037
# 11      12      8983.5699      8016.9659     17885.3093      8483.3468

# %%
sns.heatmap(pivot_year_profit,annot=True)
# Out:
# <Axes: ylabel='months'>

# %% [markdown]
# # observation
# - we can see that september there is consitent profit over the 4 year.
# - in the month of april ther is consistent decrease in profit over the 4 year.

# %%
# 3. **Consistently Unprofitable Products or Categories**:
#    - Can you identify any products or categories that are consistently unprofitable?
df[df["Profit"]<0][["Product Name","Profit"]].sort_values(by="Profit").head(10)
# Out:
#                                            Product Name     Profit
# 7772          Cubify CubeX 3D Printer Double Head Print -6599.9780
# 683           Cubify CubeX 3D Printer Triple Head Print -3839.9904
# 9774          GBC DocuBind P400 Electric Binding System -3701.8928
# 3011          Lexmark MX611dhe Monochrome Laser Printer -3399.9800
# 4991               Ibico EPK-21 Electric Binding System -2929.4845
# 3151          Cubify CubeX 3D Printer Double Head Print -2639.9912
# 5310  Fellowes PB500 Electric Punch Plastic Comb Bin... -2287.7820
# 9639  Chromcraft Bull-Nose Wood Oval Conference Tabl... -1862.3124
# 1199          GBC DocuBind P400 Electric Binding System -1850.9464
# 2697  Cisco TelePresence System EX90 Videoconferenci... -1811.0784

# %%
df[df["Profit"]<0].groupby(["Category"])["Profit"].sum().sort_values()
# Out:
# Category
# Furniture         -60936.1090
# Office Supplies   -56615.2585
# Technology        -38579.9182
# Name: Profit, dtype: float64

# %%
impact=df[["Discount",'Quantity','Profit']]
impact
# Out:
#       Discount  Quantity    Profit
# 0         0.00         2   41.9136
# 1         0.00         3  219.5820
# 2         0.00         2    6.8714
# 3         0.45         5 -383.0310
# 4         0.20         2    2.5164
# ...        ...       ...       ...
# 9989      0.20         3    4.1028
# 9990      0.00         2   15.6332
# 9991      0.20         2   19.3932
# 9992      0.00         4   13.3200
# 9993      0.00         2   72.9480
#
# [9994 rows x 3 columns]

# %%
impact.corr()
# Out:
#           Discount  Quantity    Profit
# Discount  1.000000  0.008623 -0.219487
# Quantity  0.008623  1.000000  0.066253
# Profit   -0.219487  0.066253  1.000000

# %%
# 2. **Profitable Discount Ranges**:
#    - Are there any specific discount ranges that lead to higher sales or profits?
df[df["Profit"]>0]["Discount"].mode()
# Out:
# 0    0.0
# Name: Discount, dtype: float64

# %% [markdown]
# # overall obersevation of the dataset
# **Product Contribution to Sales**: Understanding which product categories contribute the most to sales can help in focusing marketing efforts and inventory management strategies. It's interesting to note the dominance of technology products and the equal contribution of furniture and office supplies.
#
# **Sales Trends Over Time**: The significant increase in sales in 2017 suggests that there might have been specific factors or strategies that contributed to this growth. Analyzing what happened in that year could provide valuable lessons for future performance.
#
# **Seasonal Patterns in Sales**: Identifying seasonal patterns in sales can help in anticipating demand fluctuations and adjusting inventory levels accordingly. The consistent increase in sales in March and the high sales in the holiday months of September to December indicate potential opportunities for targeted marketing campaigns or promotions.
#
# **Regional Sales Performance**: Knowing which states contribute the most to sales can inform decisions regarding market expansion or allocation of resources to different regions. Understanding the differences in sales performance between states can also provide insights into regional preferences or market dynamics.
#
# **Shipping Preferences**: Recognizing customers' preferred shipping modes and delivery time expectations can help in optimizing logistics operations and enhancing customer satisfaction. It's noteworthy that despite the longer delivery time for standard shipping, customers seem to accept it, indicating that other factors such as cost or reliability might outweigh speed in their decision-making process.
